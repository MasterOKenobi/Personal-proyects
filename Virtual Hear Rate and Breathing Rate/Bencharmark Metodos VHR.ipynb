# %%
from pyVHR.analysis.pipeline import Pipeline
import matplotlib.pyplot as plt
from pyVHR.analysis.multi_method_suite import TestResult

pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 24-3-22 normal.mov", 
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_CHROM',bpm_type='welch',
                                          pre_filt=False,verb=1) 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False

plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 24-3-22 normal.mov
#
# BVP extraction with method: cpu_CHROM
#
# BPM estimation with: welch
#
# ...done!

# %%
from pyVHR.analysis.pipeline import Pipeline
import matplotlib.pyplot as plt
from pyVHR.analysis.multi_method_suite import TestResult
from pyVHR.analysis.multi_method_suite import MultiMethodSuite
from pyVHR.analysis.stats import StatAnalysis
from pyVHR.plot.visualize import VisualizeParams
from pyVHR.plot.visualize import display_video
from pyVHR.plot.visualize import visualize_BPMs

# %%
visu=VisualizeParams()

# %%
display_video('Video el 24-3-22 normal.mov')
# Out:
# interactive(children=(IntSlider(value=0, description='x', max=799), Output()), _dom_classes=('widget-interact'…

# %%
BPM
# Out:
# array([73.46213531, 72.14245605, 76.10149384, 75.66159821, 76.10148621,
#        83.13977814, 79.18074036, 81.38020325, 86.65892029, 80.94031525,
#        71.70256042, 69.50309753, 73.90202332, 76.54138184, 87.97860718,
#        86.65892029, 92.81742859, 91.93763733, 96.77645874, 95.45678711,
#        83.57966614])

# %%
pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 24-3-22 normal.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_ICA',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 24-3-22 normal.mov
#
# BVP extraction with method: cpu_ICA
#
# BPM estimation with: welch
#
# ...done!

# %%
pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 24-3-22 normal.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_PCA',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 24-3-22 normal.mov
#
# BVP extraction with method: cpu_PCA
#
# BPM estimation with: welch
#
# ...done!

# %%
from pyVHR.analysis.pipeline import Pipeline
import matplotlib.pyplot as plt

pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 26-4-22 poca luz.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_CHROM',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 26-4-22 poca luz.mov
#
# BVP extraction with method: cpu_CHROM
#
# BPM estimation with: welch
#
# ...done!

# %%
pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 26-4-22 poca luz.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_ICA',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 26-4-22 poca luz.mov
#
# BVP extraction with method: cpu_ICA
#
# BPM estimation with: welch
#
# ...done!

# %%
pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 26-4-22 poca luz.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_PCA',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 26-4-22 poca luz.mov
#
# BVP extraction with method: cpu_PCA
#
# BPM estimation with: welch
#
# ...done!

# %%
from pyVHR.analysis.pipeline import Pipeline
import matplotlib.pyplot as plt

pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 26-4-22 contraluz.41.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_CHROM',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 26-4-22 contraluz.41.mov
#
# BVP extraction with method: cpu_CHROM
#
# BPM estimation with: welch
#
# ...done!

# %%
pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 26-4-22 contraluz.41.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_ICA',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 26-4-22 contraluz.41.mov
#
# BVP extraction with method: cpu_ICA
#
# BPM estimation with: welch
#
# ...done!

# %%
pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 26-4-22 contraluz.41.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='cpu_PCA',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 26-4-22 contraluz.41.mov
#
# BVP extraction with method: cpu_PCA
#
# BPM estimation with: welch
#
# ...done!

# %%
pipe = Pipeline()
time, BPM, uncertainty = pipe.run_on_video(r"Video el 26-4-22 contraluz.41.mov", verb=1,
                                           roi_approach="patches", 
                                           roi_method="convexhull",method='torch_CHROM',bpm_type='welch') 
#bpm welch , psd_clustering #roi_approach hol , patches
#roi_method faceparsing , convexhull
# pre_filt True , False 
#post_filt True , False
plt.figure()
plt.plot(time, BPM)
plt.fill_between(time, BPM-uncertainty, BPM+uncertainty, alpha=0.2)
plt.show()
# Out:
# Processing Video: Video el 26-4-22 contraluz.41.mov
#
# BVP extraction with method: torch_CHROM
#
# BPM estimation with: welch
#
# ...done!
